# %% [markdown]
# **Postgrado en Ciencias de la Computación**
# **Inteligencia Artificial (CC6021236)**
# **Semestre 2019-1**
# **Prof. Eugenio Scalise**
#
# ## Tarea 4 (Aprendizaje No Supervizado - Agrupamiento/Clustering)

# %% [markdown]
# ***(inserte sus datos personales en esta celda)***

# %% [markdown]
# En esta tarea se utilizará un set de datos con información de uso de tarjetas de crédito durante 6 meses. El objetivo es utilizar técnicas de agrupamiento/clustering (y si lo considera necesario, reducción de dimensionalidad con PCA) para hacer una segmentación de usuarios.
#
# El dataset está desplegado en este [URL en el repositorio de la materia](https://raw.githubusercontent.com/escalise/AI_Course_PG/master/assignments/cc_data.csv) y también hay un pequeño [diccionario de datos](https://raw.githubusercontent.com/escalise/AI_Course_PG/master/assignments/cc_data_dict.txt).

# %%
# lectura del dataset como un DataFrame en Pandas
import pandas as pd

url ="https://raw.githubusercontent.com/escalise/AI_Course_PG/master/assignments/cc_data.csv"
data = pd.read_csv(url)

print(data.shape)
data.head(10)
# Out:
# (8950, 18)
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
# 6  C10007   627.260806           1.000000    7091.01           6402.63
# 7  C10008  1823.652743           1.000000     436.20              0.00
# 8  C10009  1014.926473           1.000000     861.49            661.49
# 9  C10010   152.225975           0.545455    1281.60           1281.60
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# ...

# %%
# información estadística de las características
data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %% [markdown]
# Documente en este notebook (con código, gráficas y análisis) las siguientes actividades:
#
# 1. Realice los preprocesamientos y visualizaciones de las características de los datos que permitan tener una idea de los posibles clusters de usuarios a identificar.

# %% [markdown]
# 2. Utilice la técnica de k-medias (K-means) para realizar un modelo de agrupamiento. Adicionalmente, utilice la técnica del "codo" (elbow) para determinar un valor razonable para K. En el [Piazza del curso](https://piazza.com/universidad_central_de_venezuela/spring2019/cc6021236/resources) se agregó un [artículo que describe el "Elbow Method"](https://blog.cambridgespark.com/how-to-determine-the-optimal-number-of-clusters-for-k-means-clustering-14f27070048f).

# %% [markdown]
# 3. Utilice ahora clustering jerárquico (Hierarchical Clustering) con los criterios de "linkage" mencionados en clase (ward, single, complete y average) y compare los resultados.

# %% [markdown]
# 4. Concluya sobre los resultados obtenidos.

# %% [markdown]
# ### Consideraciones:
#
# - Utilice una copia de este Jupyter Notebook usando Python3 para hacer el proyecto.
# - Renombre el documento como `Tarea_4_-_Nombre1_Apellido1_-_Nombre2_Apellido2.ipynb`
# - Agregue todas las celdas necesarias tanto de código como markdown para que el desarrollo de cada pregunta sea fácil de leer y entender.
# - Agregue una celda de referencias y cite **todo** recurso que utilice. Utilice formato IEEE para las referencias.
# - Esta tarea se puede realizar en grupos de dos personas.
# - Para la entrega, hospede su solución en http://colab.research.google.com. La fecha y hora de la última modificación del documento será considerada el *timestamp* de entrega. Para mayor seguridad, envíe también el notebook como una anexo por correo a `escalise at gmail dot com`.
# - Todas las celdas de código de la entrega deben estar ejecutadas para facilitar la corrección.
# - La fecha de entrega de esta tarea es el domingo 03/11/2019, 11:59:59 PM (VET time).
